# %%
# !pip install transformers

# %%
from transformers import (AutoTokenizer,
                          AutoModelForQuestionAnswering,
                          BitsAndBytesConfig,
                          pipeline)

# %%
# !pip install torch

# %%
# !pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 7.5 MB/s eta 0:00:00
# ...

# %%
# !pip install -U bitsandbytes

# %%
import torch
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
# !pip uninstall bitsandbytes
# Out:
# Found existing installation: bitsandbytes 0.43.3
# Uninstalling bitsandbytes-0.43.3:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/bitsandbytes-0.43.3.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/bitsandbytes/*
#     /usr/local/lib/python3.10/dist-packages/tests/*
# Proceed (Y/n)? y
#   Successfully uninstalled bitsandbytes-0.43.3

# %%
# !pip install bitsandbytes
# Out:
# ...
#   Using cached bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# ...
# Using cached bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl (137.5 MB)
# ...

# %%
# !pip install -U bitsandbytes accelerate
# Out:
# ...
#   Using cached bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# ...
# Using cached bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl (137.5 MB)
# ...

# %%
from transformers import AutoModelForCausalLM
model_name="mhd77/llama3-python-code-generation"
tokenizer = AutoTokenizer.from_pretrained("mhd77/llama3-python-code-generation",torch_dtype="auto")
model = AutoModelForCausalLM.from_pretrained(model_name,torch_dtype="auto",load_in_4bit=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# pytorch_model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the prompt
prompt = """
Write the function definition for finding the average of numbers in Python. Only return the function definition without any additional text.
"""

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Move inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate text
with torch.no_grad():
    outputs = model.generate(**inputs)

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Extract the function definition by removing the prompt from the generated text
function_definition = generated_text[len(prompt):].strip()

# Print the function definition
print(function_definition)
# Out:
# def average(numbers):
#     return sum(numbers) / len(numbers)

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the prompt
prompt = """
Write the function definition for finding the average of three numbers in Python. Only return the function definition without any additional text.
"""

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Move inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate text
with torch.no_grad():
    outputs = model.generate(**inputs)

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Extract the function definition by removing the prompt from the generated text
function_definition = generated_text[len(prompt):].strip()

# Print the function definition
print(function_definition)
# Out:
# def average(a, b, c):
#     return (a + b + c) / 3.0

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the prompt
prompt = """
Write the function definition for finding the addition two numbers in Python. Only return the function definition without any additional text.
"""

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Move inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate text
with torch.no_grad():
    outputs = model.generate(**inputs)

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Extract the function definition by removing the prompt from the generated text
function_definition = generated_text[len(prompt):].strip()

# Print the function definition
print(function_definition)
# Out:
# def addition(a, b):
#     return a + b
# ```python
# def addition(a, b):
#     return a + b
# ```

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the prompt
prompt = """
Write the function definition for finding the sum of two numbers in Python. Only return the function definition without any additional text.
"""

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Move inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate text
with torch.no_grad():
    outputs = model.generate(**inputs)

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Extract the function definition by removing the prompt from the generated text
function_definition = generated_text[len(prompt):].strip()

# Print the function definition
print(function_definition)
# Out:
# def sum_numbers(num1, num2):
#     return num1 + num2

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the prompt
prompt = """
Write the function definition for finding the sum of numbers in Python. Only return the function definition without any additional text.
"""

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Move inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate text
with torch.no_grad():
    outputs = model.generate(**inputs)

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Extract the function definition by removing the prompt from the generated text
function_definition = generated_text[len(prompt):].strip()

# Print the function definition
print(function_definition)
# Out:
# def sum_numbers(numbers):
#     total = 0
#     for num in numbers:
#         total += num
#     return total

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the prompt
prompt = """
Write the function definition for finding the maximum value in a list of numbers in Python. Only return the function definition without any additional text.
"""

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Move inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate text
with torch.no_grad():
    outputs = model.generate(**inputs)

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Extract the function definition by removing the prompt from the generated text
function_definition = generated_text[len(prompt):].strip()

# Print the function definition
print(function_definition)
# Out:
# def find_max_value(numbers):
#     return max(numbers)

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the prompt
prompt = """
Write the function definition for checking if a string is a palindrome in Python. Only return the function definition without any additional text.
"""

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Move inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate text
with torch.no_grad():
    outputs = model.generate(**inputs)

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Extract the function definition by removing the prompt from the generated text
function_definition = generated_text[len(prompt):].strip()

# Print the function definition
print(function_definition)
# Out:
# def is_palindrome(s):
#     return s == s[::-1]

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the prompt
prompt = """
Write the function definition for reversing a list in Python. Only return the function definition without any additional text.
"""

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Move inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate text
with torch.no_grad():
    outputs = model.generate(**inputs)

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Extract the function definition by removing the prompt from the generated text
function_definition = generated_text[len(prompt):].strip()

# Print the function definition
print(function_definition)
# Out:
# def reverse_list(list):
#     return list[::-1]

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the prompt
prompt = """
Write the function definition for counting the number of vowels in a string in Python. Only return the function definition without any additional text.
"""

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Move inputs to the same device as the model
inputs = {key: value.to(model.device) for key, value in inputs.items()}

# Generate text
with torch.no_grad():
    outputs = model.generate(**inputs)

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Extract the function definition by removing the prompt from the generated text
function_definition = generated_text[len(prompt):].strip()

# Print the function definition
print(function_definition)
# Out:
# def count_vowels(string):
#     vowels = "aeiouAEIOU"
#     count = 0
#     for char in string:
#         if char in vowels:
#             count += 1
#     return count
# def count_vowels(string):
#     vowels = "aeiouAEIOU"
#     count = 0
#     for char in string:
#         if char in vowels:
#             count += 1
#     return count
# def count_vowels(string):
#     vowels = "aeiouAEIOU"
#     count = 0
#     for char in string:
#         if char in vowels:
#             count += 1
#     return count
# def count_vowels(string):
#     vowels = "aeiouAEIOU"
#     count = 0
#     for char in string:
#         if char in vowels:
#             count += 1
#     return count
# def count_vowels(string):
#     vowels = "aeiouAEIOU"
#     count = 0
#     for char in string:
#         if char in vowels:
#             count += 1
#     return count
# def count_vowels(string):
#     vowels = "aeiouAEIOU"
#     count = 0
#     for char in string:
#         if char in vowels:
# ...
